# %% [markdown]
# <a href="https://colab.research.google.com/github/srivas-ITB/testingGoogleColab/blob/main/Prova1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prueba 1

# %% [markdown]
# ## Hello world

# %%
#moviendo

# %%
nombre = ""
while not nombre.strip():
    nombre = input("¿Cuál es tu nombre? ")
    if not nombre.strip():
        print("El nombre no puede estar vacío. Por favor, introduce un nombre.")
print(f"¡Hola, {nombre.strip()}!")
# Out:
# ¿Cuál es tu nombre? pepee
# ¡Hola, pepee!

# %%
## el último

# %%
##otro último

# %% [markdown]
# esto es texto
